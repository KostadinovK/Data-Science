# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
accidents_data = pd.read_csv("accidents.csv")
accidents_data
# Out:
#   Miles from Home  % of Accidents
# 0     less than 1              23
# 1          1 to 5              29
# 2         6 to 10              17
# 3        11 to 15               8
# 4        16 to 20               6
# 5         over 20              17

# %%
with open("accidents.csv","r") as file:
    content = file.read()
for line in content.split("\n"):
    print(line.split(","))
# Out:
# ['Miles from Home', '% of Accidents']
# ['less than 1', '23']
# ['1 to 5', '29']
# ['6 to 10', '17']
# ['11 to 15', '8']
# ['16 to 20', '6']
# ['over 20', '17']

# %%
print(accidents_data.shape)
print(accidents_data.index)
print(accidents_data.columns)
print(accidents_data.dtypes)
# Out:
# (6, 2)
# RangeIndex(start=0, stop=6, step=1)
# Index(['Miles from Home', '% of Accidents'], dtype='object')
# Miles from Home    object
# % of Accidents      int64
# dtype: object

# %%
data = pd.read_fwf("http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data",header = None)
plt.hist(data.loc[:,3])
plt.show()

# %%
tripdata = pd.read_excel("green_tripdata_2015-09.xls")
tripdata
# Out:
#        VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0             2  2015-09-01 00:02:34   2015-09-01 00:02:38                  N
# 1             2  2015-09-01 00:04:20   2015-09-01 00:04:24                  N
# 2             2  2015-09-01 00:01:50   2015-09-01 00:04:24                  N
# 3             2  2015-09-01 00:02:36   2015-09-01 00:06:42                  N
# 4             2  2015-09-01 00:00:14   2015-09-01 00:04:20                  N
# 5             2  2015-09-01 00:00:39   2015-09-01 00:05:20                  N
# 6             2  2015-09-01 00:00:52   2015-09-01 00:05:50                  N
# 7             2  2015-09-01 00:02:15   2015-09-01 00:05:34                  N
# 8             2  2015-09-01 00:02:36   2015-09-01 00:07:20                  N
# 9             2  2015-09-01 00:02:13   2015-09-01 00:07:23                  N
# 10            2  2015-09-01 00:01:12   2015-09-01 00:05:03                  N
# ...

# %%
books_data = pd.read_json("https://openlibrary.org/api/books?bibkeys=ISBN:9780345354907,ISBN:0881847690,LCCN:2005041555,ISBN:0060957905&format=json",orient = "index")
books_data
# Out:
#                                bib_key  \
# ISBN:0060957905        ISBN:0060957905
# ISBN:0881847690        ISBN:0881847690
# ISBN:9780345354907  ISBN:9780345354907
# LCCN:2005041555        LCCN:2005041555
#
#                                                              info_url  \
# ISBN:0060957905     https://openlibrary.org/books/OL6784868M/Tales...
# ISBN:0881847690     https://openlibrary.org/books/OL22232644M/Watc...
# ISBN:9780345354907  https://openlibrary.org/books/OL9831606M/The_C...
# LCCN:2005041555     https://openlibrary.org/books/OL3421202M/At_th...
#
#                        preview  \
# ISBN:0060957905         noview
# ISBN:0881847690         borrow
# ISBN:9780345354907  restricted
# LCCN:2005041555         borrow
#
#                                                           preview_url  \
# ISBN:0060957905     https://openlibrary.org/books/OL6784868M/Tales...
# ISBN:0881847690     https://archive.org/details/watchersoutoftim00...
# ...

# %%
accidents_data.plot.box()
accidents_data.hist()
plt.show()
