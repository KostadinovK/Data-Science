# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi,2000)
y = np.sin(x)
plt.plot(x,y)

# %%
nums = np.random.randint(1,11,1000)
plt.hist(nums)
plt.show()

# %%
print(plt.style.available)
plt.style.use("seaborn")
# Out:
# ['seaborn-whitegrid', 'seaborn-deep', 'seaborn-bright', 'seaborn-muted', 'seaborn-dark', 'seaborn-poster', 'fast', 'seaborn-paper', 'bmh', 'grayscale', 'seaborn-white', 'classic', 'seaborn-colorblind', 'Solarize_Light2', 'fivethirtyeight', 'seaborn-notebook', 'seaborn-darkgrid', 'seaborn-pastel', 'seaborn-talk', 'tableau-colorblind10', 'seaborn-ticks', 'seaborn-dark-palette', 'seaborn', 'dark_background', '_classic_test', 'ggplot']

# %%
sizes = [20,40,10,30]
plt.pie(sizes, labels=["Name1","Name2","Name3","Name4"])
plt.gca().set_aspect("equal")

# %%
iris_data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",header = None)
iris_data.columns = ["sepal_length","sepal_width","petal_length","petal_width","class"]
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
iris_data.groupby("class").mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# class
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %%
iris_data.groupby("class").std()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# class
# Iris-setosa          0.352490     0.381024      0.173511     0.107210
# Iris-versicolor      0.516171     0.313798      0.469911     0.197753
# Iris-virginica       0.635880     0.322497      0.551895     0.274650

# %%
nuclear_data = pd.read_csv("https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/boot/nuclear.csv")
nuclear_data = nuclear_data.drop("Unnamed: 0",axis = 1)

# %%
price = nuclear_data.cost.mean()
print(price)
# Out:
# 461.5603124999999

# %%
nuclear_data.head()
north_east_data = nuclear_data[nuclear_data["ne"] == 1]
north_east_data.shape
# Out:
# (8, 11)

# %%
nuclear_data.head()
costs = nuclear_data.cost
dates = nuclear_data.date
plt.scatter(dates,costs)
plt.show()
nuclear_data.head()
# Out:
#      cost   date  t1  t2   cap  pr  ne  ct  bw  cum.n  pt
# 0  460.05  68.58  14  46   687   0   1   0   0     14   0
# 1  452.99  67.33  10  73  1065   0   0   1   0      1   0
# 2  443.22  67.33  10  85  1065   1   0   1   0      1   0
# 3  652.32  68.00  11  67  1065   0   1   1   0     12   0
# 4  642.23  68.00  11  78  1065   1   1   1   0     12   0

# %%
caps = nuclear_data[nuclear_data["pr"] == 1].cap
caps.max()
# Out:
# 1065
