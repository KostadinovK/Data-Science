# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from skimage.io import imread,imshow
from scipy.ndimage.filters import convolve

from collections import Counter
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from sklearn.datasets import fetch_20newsgroups
from skimage.filters import try_all_threshold

from skimage.morphology import binary_opening,square

# %%
tiger_image = imread("http://www.abc.net.au/news/image/7318414-3x2-940x627.jpg")
imshow(tiger_image)
# Out:
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/kosta/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
red_channel = tiger_image[:,:,0]
green_channel = tiger_image[:,:,1]
blue_channel = tiger_image[:,:,2]
imshow(red_channel)
# Out:
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/kosta/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
imshow(green_channel)
# Out:
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/kosta/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
imshow(blue_channel)
# Out:
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/kosta/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
plt.hist(red_channel.ravel(),color="red",bins = 256,alpha = 0.5)
plt.hist(green_channel.ravel(),color="green",bins = 256, alpha = 0.5)
plt.hist(blue_channel.ravel(),color="blue",bins = 256, alpha = 0.5)
plt.show()

# %%
average = tiger_image.mean(axis = 2)
imshow(average,cmap = "gray")
# Out:
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "
# /home/kosta/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
tiger_grayscale = 0.299 * red_channel + 0.587 * green_channel + 0.114 * blue_channel
imshow(tiger_grayscale,cmap = "gray")
# Out:
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "
# /home/kosta/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
box_blur_kernel = np.array([
    [1,1,1],
    [1,1,1],
    [1,1,1]]) / 9
blurred = convolve(tiger_grayscale,box_blur_kernel)
plt.imshow(tiger_grayscale[300:400,400:600],cmap = "gray")
plt.title("Normal")
plt.show()
plt.imshow(blurred[300:400,400:600],cmap = "gray")
plt.title("Blurred")
plt.show()

# %%
with open("alice.txt","r") as file:
    alice = file.read()
print(len(alice))
# Out:
# 164108

# %%
counter = Counter(alice)
counter.most_common(20)
# Out:
# [(' ', 29580),
#  ('e', 15243),
#  ('t', 11754),
#  ('o', 9348),
#  ('a', 9172),
#  ('n', 7926),
#  ('i', 7881),
#  ('h', 7669),
#  ('s', 7054),
#  ('r', 6481),
#  ('d', 5275),
#  ('l', 5111),
#  ('u', 3926),
#  ('c', 2843),
#  ('g', 2766),
#  ('w', 2725),
#  (',', 2566),
#  ('y', 2489),
#  ('m', 2272),
#  ('\n', 2266)]

# %%
word_counter = Counter(re.split("\\W+",alice.lower()))
word_counter.most_common(20)
# Out:
# [('the', 1825),
#  ('and', 944),
#  ('to', 809),
#  ('a', 695),
#  ('of', 632),
#  ('it', 610),
#  ('she', 553),
#  ('i', 546),
#  ('you', 481),
#  ('said', 462),
#  ('in', 432),
#  ('alice', 404),
#  ('was', 358),
#  ('that', 330),
#  ('as', 274),
#  ('her', 248),
#  ('with', 228),
#  ('at', 227),
#  ('s', 222),
#  ('t', 218)]

# %%
alice_words = re.split("\\W+",alice.lower())
stop = stopwords.words("english")
counter_without_stopers = Counter([w for w in alice_words if w not in stop])
counter_without_stopers.most_common(20)
# Out:
# [('said', 462),
#  ('alice', 404),
#  ('little', 129),
#  ('one', 106),
#  ('gutenberg', 93),
#  ('know', 88),
#  ('project', 87),
#  ('like', 85),
#  ('would', 83),
#  ('went', 83),
#  ('could', 78),
#  ('queen', 76),
#  ('thought', 74),
#  ('time', 71),
#  ('see', 70),
#  ('well', 63),
#  ('king', 63),
#  ('turtle', 60),
#  ('way', 58),
#  ('began', 58)]

# %%
stemmer = PorterStemmer()
alice_without_stopwords = [w for w in alice_words if w not in stop]
stemmer.stem(alice_without_stopwords[1])
# Out:
# 'project'

# %%
newsgroups = fetch_20newsgroups()
newsgroups.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
hamburger_image = imread("http://23.97.184.10/assets/courseware/v1/692dbe85139f974150d80f57becfe093/asset-v1:SoftUni+DS101+June-2018+type@asset+block/hamburger.jpg")
imshow(hamburger_image)
print(hamburger_image.size)
# Out:
# 783126
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/kosta/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
red = hamburger_image[:,:,0]
green = hamburger_image[:,:,1]
blue = hamburger_image[:,:,2]
plt.imshow(red, cmap = "gray")
plt.title("Red Channel")
plt.show()

plt.imshow(green, cmap = "gray")
plt.title("Green Channel")
plt.show()

plt.imshow(blue, cmap = "gray")
plt.title("Blue Channel")
plt.show()

print(red.mean())
# Out:
# 90.08790156373304

# %%
selem = square(3)
binary_burger = binary_opening(blue,selem)
imshow(binary_burger)
n_white_pix = np.sum(binary_burger == 1)
print('Number of white pixels:', n_white_pix)
# Out:
# Number of white pixels: 182908
# /home/kosta/anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/kosta/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
with open("book.txt","r") as file:
    book = file.read()
print(len(book))
# Out:
# 704175

# %%
word_counter = Counter(re.split("\\W+",book.lower()))
print(word_counter["pride"])
print(word_counter["prejudice"])
# Out:
# 53
# 11

# %%
book_words = re.split("\\W+",book.lower())
stop = stopwords.words("english")
counter_without_stopers = Counter([w for w in book_words if w not in stop])
counter_without_stopers.most_common(20)
# Out:
# [('mr', 785),
#  ('elizabeth', 635),
#  ('could', 527),
#  ('would', 468),
#  ('darcy', 417),
#  ('said', 401),
#  ('mrs', 343),
#  ('much', 327),
#  ('bennet', 323),
#  ('must', 315),
#  ('bingley', 306),
#  ('jane', 295),
#  ('miss', 283),
#  ('one', 270),
#  ('know', 237),
#  ('though', 226),
#  ('well', 224),
#  ('never', 218),
#  ('sister', 218),
#  ('soon', 216)]
